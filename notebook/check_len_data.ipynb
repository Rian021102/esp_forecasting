# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/Users/rianrachmanto/miniforge3/project/esp_new.csv')
print(df.head())
# Out:
#   Well        Date  Hours_Online  Freq  Ampere   Volt  Press_Discharge     TM  \
# 0  BC1  2011-09-02          24.0   NaN    19.2  343.2              NaN  175.0
# 1  BC1  2011-09-03          24.0   NaN    18.3  339.6              NaN  177.4
# 2  BC1  2011-09-04          24.0   NaN    18.0  341.0              NaN  177.0
# 3  BC1  2011-09-05          24.0   NaN    19.2  343.0              NaN  178.0
# 4  BC1  2011-09-06          24.0   NaN    18.3  339.6              NaN  178.4
#
#    Vibration   Gross_Rate
# 0      2.795  1577.005714
# 1      2.670  1577.005714
# 2      2.711  1577.005714
# 3      2.641  1577.005714
# 4      2.500  1577.005714

# %%
# make list of names of Well
listwell=df['Well'].unique().tolist()
print(listwell)
# Out:
# ['BC1', 'BC2', 'BS3', 'MHN-2', 'MHN-3', 'MHN-4', 'MHN-5', 'MHN-6', 'MHN-7', 'MHN-8', 'MHN-9', 'MHN-13', 'MHNW-1', 'MHNW-2', 'MHNW-3', 'YO-4A', 'YO-9SI', 'YW-1', 'YW-8SI', 'YW-12SI', 'YN-8SI', 'YN-9SI', 'YN-16HZ', 'YN-17HZ', 'YN-19HZ', 'YKN-23HZ', 'YKN-24HZ', 'YN-7SI', 'YN-10SI', 'YN-11SI', 'YN-12SI', 'YCA-2SI', 'YCA-5HZ', 'YCA-7HZ', 'YCA-8HZ', 'YCA-10HZ', 'YCA-11HZ', 'YCB-1HZ', 'YCB-2HZ', 'YCB-4HZ', 'YCB-8HZ', 'YCB-9SI']

# %%
def plot_voltage(df,listwell):
    for key in listwell:
        plt.figure()
        df[df['Well']==key].plot(x='Date',y='Press_Discharge')
        plt.title(key)
        plt.show()

# %%
plot_voltage(df,listwell)
